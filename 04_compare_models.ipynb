# %% [markdown]
# # 04_compare_models
#
# ## 목적
# - `DummyClassifier`, `LogisticRegression`, `MLP`, `LSTM`를 한 표에서 공정하게 비교한다.
# - threshold tuning, 지표 선택, 발표용 결론 문장을 일관되게 정리한다.
#
# ## 입력 파일
# - 모델별 test prediction 파일
# - 모델별 validation threshold 기록
# - `results/model_comparison_template.csv`
#
# ## 결과 해석 원칙
# - `LogisticRegression`도 같은 기준으로 threshold tuning을 해야 공정하다.
# - accuracy만으로 결론을 내리지 않는다.
# - 필요하면 ROC curve와 함께 PR curve도 반드시 제시한다.
# - `LSTM`을 무조건 최고라고 쓰지 않고, 지표별 장단점을 함께 설명한다.

# %%
from pathlib import Path

import pandas as pd

comparison_path = Path("results/model_comparison_template.csv")
comparison = pd.read_csv(comparison_path)
comparison
