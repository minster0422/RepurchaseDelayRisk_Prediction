# %% [markdown]
# # 03_train_lstm
#
# ## 목적
# - LSTM을 순차 패턴 기반 모델로 정의하고, MLP와의 비교 의미를 분명히 한다.
# - 핵심 질문은 **순차 정보가 실제 예측에 도움이 되는가**다.
#
# ## 입력 파일
# - `01_prepare_data.ipynb`에서 복원해야 할 sequence 입력
# - 같은 사용자 기준 train / val / test split
#
# ## 출력 파일
# - 권장: `results/test_predictions_lstm.csv`
# - 권장: `results/thresholds.json`
#
# ## NOTE
# - 현재 저장소에는 sequence 입력 생성 코드가 없다.
# - 따라서 이 노트북은 현재 시점에서 **실험 설계 문서 겸 실행 뼈대** 역할을 한다.
# - 실제 비교를 위해서는 `LogisticRegression`, `MLP`와 동일한 split과 동일한 label 정의를 써야 한다.

# %%
SEQUENCE_SOURCE = None

print("현재 저장소에는 LSTM용 sequence 입력이 없어, 이 노트북은 설계 문서로 사용합니다.")
print("필수 조건: 같은 사용자 split, 같은 label 정의, validation threshold tuning")
